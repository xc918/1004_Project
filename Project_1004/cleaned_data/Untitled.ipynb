# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

taxi_o = pd.read_csv('Taxi_Data.csv',index_col=0)
taxi_0 = taxi_o[taxi_o.Location_ID ==0]
taxi = taxi_o[taxi_o.Location_ID !=0]
uber2014 = pd.read_csv('Uber-2014.csv',index_col=0)
uber2015 = pd.read_csv('Uber-2015.csv',index_col=0)

# %%
uber2014['Mon_Counts'] = uber2014.groupby(['Month'])['date'].transform('count')
uber2015['Mon_Counts'] = uber2015.groupby(['Month'])['Date'].transform('count')

uber2014['Loc_Counts'] = uber2014.groupby(['Location_ID'])['Month'].transform('count')
uber2015['Loc_Counts'] = uber2015.groupby(['locationID'])['Month'].transform('count')

uber2014 = uber2014.sort(columns='Month', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
uber2015 = uber2015.sort(columns='Month', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

#taxi['Loc_Counts'] = taxi.groupby(['Location_ID'])['Month'].transform('count')
#taxi['Mon_Counts'] = taxi.groupby(['Month'])['Date'].transform('count')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:8: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
uber2015[uber2015.locationID==1]

# %% [markdown]
# # Monthly Counts Uber VS Taxi

# %%
#uber 2014
a = uber2014.Mon_Counts.unique().tolist()
b = sorted(uber2014.Month.unique().tolist())
u = ['Uber_Counts']

df2014 = pd.DataFrame(a,b,columns=u)
df2014.plot(kind='bar',width=0.35,rot=0, color = 'skyblue', alpha= 0.7, edgecolor='w')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Monthly Trip Counts', fontsize=14)
plt.title('Uber 2014 Apr to Sept', fontsize = 14)
plt.show()

# %%
#uber2015
c = uber2015.Mon_Counts.unique().tolist()
d = sorted(uber2015.Month.unique().tolist())
df2015 = pd.DataFrame(c,d,columns=u)
df2015.plot(kind='bar',width=0.35,rot=0, color = 'purple', alpha= 0.7, edgecolor='w')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Monthly Trip Counts', fontsize=14)
plt.title('Uber 2015 Jan to Jun', fontsize = 14)
plt.show()

# %%
#taxi
taxi2014 = taxi[taxi['Year'] == 2014.]
taxi2015 = taxi[taxi['Year'] == 2015.]
mon1 = [4,5,6,7,8,9]
mon2 = [1,2,3,4,5,6]
taxi2014_49 = taxi2014.loc[taxi2014['Month'].isin(mon1)]
taxi2015_16 = taxi2015.loc[taxi2015['Month'].isin(mon2)]

# %%
#taxi 2014
tm1 = taxi2014_49.groupby(['Month'])['Count'].sum().tolist()
#tm1 = taxi2014_49.Mon_Counts.unique().tolist()
t = ['Taxi_Counts']
dftm1 = pd.DataFrame(tm1, mon1,columns=t)
dftm1.plot(kind='bar',width=0.35,rot=0, color = 'orange', alpha= 0.7, edgecolor='w')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Monthly Trip Counts', fontsize=14)
plt.title('Taxi 2014 Apr to Sept', fontsize = 14)
plt.show()

# %%
tm1 = taxi2014_49.groupby(['Month'])['Count'].sum().tolist()
tm1
# Out:
# [14321675.0, 14421682.0, 13449463.0, 12755920.0, 23730926.0, 13111677.0]

# %%
#taxi 2015
tm2 = taxi2015_16.groupby(['Month'])['Count'].sum().tolist()
dftm2 = pd.DataFrame(tm2, mon2,columns=t)
dftm2.plot(kind='bar',width=0.35,rot=0, color = 'pink', alpha= 0.7, edgecolor='w')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Monthly Trip Counts', fontsize=14)
plt.title('Taxi 2015 Jan to Jun', fontsize = 14)
plt.show()

# %%
#cc = taxi2014_49.groupby(['Month'])['Count'].sum()#.count()
vs1 = [df2014,dftm1]
vs1 = pd.concat(vs1,axis =1)
df2222 = pd.DataFrame(vs1)#, columns=['a', 'b'])
df2222.plot.bar()
plt.show()

# %%
vs2 = [df2015,dftm2]
vs2 = pd.concat(vs2,axis =1)
df2222 = pd.DataFrame(vs2)#, columns=['a', 'b'])
df2222.plot.bar()
plt.show()

# %% [markdown]
# # Location counts Uber VS Taxi

# %%
# u14_loc_c = uber2014.Loc_Counts.tolist()
# u14_loc_id = uber2014.Location_ID.unique().tolist()
# u14 = pd.DataFrame(u14_loc_c,u14_loc_id)
# u14.plot(kind='bar',width=0.35,rot=0, color = 'lightyellow', alpha= 0.7, edgecolor='w')
# plt.xlabel('LocationID', fontsize=14)
# plt.ylabel('Geographically Trip Counts', fontsize=14)
# plt.title('Uber 2014 Apr to Sept', fontsize = 14)
# plt.show()

# %%
oo = uber2014.groupby(['Location_ID']).count()
q = oo['Loc_Counts']
b = oo.index.values.tolist()
plt.figure()
plt.plot(b,q)
plt.show()

# %%
yyy = taxi.groupby(['Time'])['Count'].sum()#.tolist()

# %%
#yy = yyy[-1]
y = range(0,24,1)
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
#plt.plot(y,yyy)
yyy.plot(kind='bar',width=0.8,rot=0, color = 'skyblue', alpha= 0.5, edgecolor='r')
plt.xlabel('Hour', fontsize=8)
plt.ylabel('Trip', fontsize=8)
plt.title(' Hourly Trip ', fontsize = 14)

# %%
k = [168753293,165369333,172834899,174391308,169903431,173207306,143807798]
k = pd.DataFrame(k)
#k = np.asarray(k)
#k = k.sum()/6.
k.describe()
# Out:
#                   0
# count  7.000000e+00
# mean   1.668953e+08
# std    1.063934e+07
# min    1.438078e+08
# 25%    1.670613e+08
# 50%    1.699034e+08
# 75%    1.730211e+08
# max    1.743913e+08

# %%
170743262-166895300

# %%
8550405/5.
# Out:
# 1710081.0

# %%
tc = taxi.groupby(['Year'])['Count'].sum()
print tc
print tc.sum()
tc.plot(kind='bar',width=0.8,rot=0, color = 'orange', alpha= 0.5, edgecolor='g')
plt.ylim([1.3e8,1.8e8])
# Out:
# Year
# 2009    168753293
# 2010    165369333
# 2011    172834899
# 2012    174391308
# 2013    169903431
# 2014    173207306
# 2015    143807798
# Name: Count, dtype: float64
# 1168267368.0
# (130000000.0, 180000000.0)

# %%
ha = taxi2014_49.groupby('Time')['Count'].sum()
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
ha.plot(kind='bar',width=0.8,rot=0, color = 'orange', alpha= 0.5, edgecolor='g')

# %%
he = uber2014.groupby(['time'])['Loc_Counts'].count()
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
he.plot(kind='bar',width=0.8,rot=0, color = 'purple', alpha= 0.5, edgecolor='g')

# %%
zha = taxi2015_16.groupby('Time')['Count'].sum()
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
zha.plot(kind='bar',width=0.8,rot=0, color = 'grey', alpha= 0.5, edgecolor='g')

# %%
her = uber2015.groupby(['time'])['Loc_Counts'].count()
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
her.plot(kind='bar',width=0.8,rot=0, color = 'pink', alpha= 0.5, edgecolor='g')

# %% [markdown]
# # Locking location of big demand of Uber
# # Then compare with taxi
# # Then looking for demand changing

# %%
zhu = uber2014.groupby(['Location_ID'])['Mon_Counts'].count()
zhu = pd.DataFrame(zhu)
zhu = zhu.sort(columns= 'Mon_Counts', ascending=False)
zhu = zhu[zhu.Mon_Counts >50000]
plt.figure(dpi=1000, frameon=True,figsize=(10,4))
zhu.plot(kind='bar',width=0.8,rot=0, color = 'purple', alpha= 0.5, edgecolor='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
www = uber2014.groupby(['time','Location_ID'])['Loc_Counts'].count()
www = www.loc[16,:]
www = pd.DataFrame(www)
#www = www['Loc_Counts']
#www = pd.DataFrame(www)
www = www.sort(columns= 'Loc_Counts', ascending=False)
www = www[0:34]
www.plot(kind='barh',width=0.8,rot=0, color = 'lightgrey', alpha= 0.5, edgecolor='r')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
hers = uber2015.groupby(['time','locationID'])['Loc_Counts'].count()
#hers = pd.DataFrame(hers)
hers_peak = hers.loc[16, :]
#hers_peak = hers_peak['Loc_Counts']
hersss = pd.DataFrame(hers_peak)
hersss = hersss.sort(columns='Loc_Counts', ascending=False)
hersss = hersss[0:34]
plt.figure(dpi=1000, frameon=True,figsize=(12,4))
hersss.plot(kind='barh',width=0.8,rot=0, color = 'lightgreen', alpha= 0.5, edgecolor='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
ri = taxi2014_49.groupby(['Time','Location_ID'])['Count'].sum()
ri = ri.loc[16, :]
ri = pd.DataFrame(ri)
ri = ri.sort(columns='Count',ascending=False)
ri = ri[0:34]
plt.figure(dpi=1000, frameon=True,figsize=(10,12))
ri.plot(kind='barh',width=0.8,rot=0, color = 'y', alpha= 0.5, edgecolor='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
rio = taxi2015_16.groupby(['Time','Location_ID'])['Count'].sum()
rio = rio.loc[16, :]
rio = pd.DataFrame(rio)
rio = rio.sort(columns='Count',ascending=False)
rio = rio[0:34]
rio.plot(kind='barh',width=0.8,rot=0, color = 'r', alpha= 0.5, edgecolor='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
taxi2013 = taxi[taxi['Year'] == 2013.]

# %%
pre = taxi2013.groupby(['Time', 'Location_ID'])['Count'].sum()
pre = pre.loc[16,:]
pre = pd.DataFrame(pre)
pre = pre.sort(columns = 'Count', ascending=False)
pre = pre[0:34]
pre.plot(kind='barh',width=0.8,rot=0, color = 'pink', alpha= 0.5, edgecolor='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
rii = taxi2014.groupby(['Time','Location_ID'])['Count'].sum()
rii = rii.loc[16, :]
rii = pd.DataFrame(rii)
rii = rii.sort(columns='Count',ascending=False)
rii = rii[0:34]

riq = taxi2015.groupby(['Time','Location_ID'])['Count'].sum()
riq = riq.loc[16, :]
riq = pd.DataFrame(rio)
riq = riq.sort(columns='Count',ascending=False)
riq = riq[0:34]
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
ll = [pre, rii, riq]#,
lll = pd.concat(ll,axis = 1)

lll.plot(kind='bar',width=0.8,rot=0, color = 'rbg', alpha= 0.5, edgecolor='g')

# %%
ss = [www,hersss]
sss = pd.concat(ss,axis = 1)
sss.plot(kind='bar',width=0.8,rot=0, color = 'rg', alpha= 0.5, edgecolor='g')

# %%
sss = sss.fillna(0)

# %%
z = [ri,rio,www,hersss]
z = pd.concat(z,axis=1)
#z = z.fillna(0)
z1 = z.dropna()
#z1

z1.plot(kind='bar',width=0.8,rot=0, color = 'rgby', alpha= 0.5, edgecolor='g')

# %% [markdown]
# # all years, taxi needs, different nbhd

# %%
taxi_2009 = taxi[taxi['Year'] == 2009.]
taxi_2010 = taxi[taxi['Year'] == 2010.]
taxi_2011 = taxi[taxi['Year'] == 2011.]
taxi_2012 = taxi[taxi['Year'] == 2012.]
taxi_2013 = taxi[taxi['Year'] == 2013.]
taxi_2014 = taxi[taxi['Year'] == 2014.]
taxi_2015 = taxi[taxi['Year'] == 2015.]

# %%
mht = [4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263]
brkl = [11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257]
brx = [3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259]
qus = [2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260]
sti = [5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251]

# %%
yr = [2009.,2010.,2011.,2012.,2013.,2014.,2015.]

# %%
taxi_man = taxi.groupby(['Location_ID']).count()

# %%
taxi_man = pd.DataFrame(taxi_man)
taxi_man
# Out:
#               Year  Month   Date   Time  Num_Passenger  Trip_distance  \
# Location_ID
# 1            62038  62038  62038  62038          62038          62038
# 2             8656   8656   8656   8656           8656           8656
# 3             7416   7416   7416   7416           7416           7416
# 4            62051  62051  62051  62051          62051          62051
# 5              720    720    720    720            720            720
# 6             7837   7837   7837   7837           7837           7837
# 7            62072  62072  62072  62072          62072          62072
# 8            60296  60296  60296  60296          60296          60296
# 9             6113   6113   6113   6113           6113           6113
# 10           56788  56788  56788  56788          56788          56788
# 11           15587  15587  15587  15587          15587          15587
# 12           61923  61923  61923  61923          61923          61923
# 13           62014  62014  62014  62014          62014          62014
# 14           33844  33844  33844  33844          33844          33844
# 15            7586   7586   7586   7586           7586           7586
# 16            5949   5949   5949   5949           5949           5949
# 17           40581  40581  40581  40581          40581          40581
# 18            7393   7393   7393   7393           7393           7393
# 19           24451  24451  24451  24451          24451          24451
# 20            5437   5437   5437   5437           5437           5437
# 21           15690  15690  15690  15690          15690          15690
# 23           34282  34282  34282  34282          34282          34282
# 24           62077  62077  62077  62077          62077          62077
# 25           62052  62052  62052  62052          62052          62052
# 26           20038  20038  20038  20038          20038          20038
# 27           13432  13432  13432  13432          13432          13432
# 28           55216  55216  55216  55216          55216          55216
# 29           16294  16294  16294  16294          16294          16294
# 30           10155  10155  10155  10155          10155          10155
# 31            4192   4192   4192   4192           4192           4192
# ...            ...    ...    ...    ...            ...            ...
# 229          62083  62083  62083  62083          62083          62083
# 230          62082  62082  62082  62082          62082          62082
# 231          62069  62069  62069  62069          62069          62069
# 232          58136  58136  58136  58136          58136          58136
# 233          62067  62067  62067  62067          62067          62067
# 234          62081  62081  62081  62081          62081          62081
# 235          19012  19012  19012  19012          19012          19012
# 236          62083  62083  62083  62083          62083          62083
# 238          61396  61396  61396  61396          61396          61396
# 240          22137  22137  22137  22137          22137          22137
# 241           9224   9224   9224   9224           9224           9224
# 242           7580   7580   7580   7580           7580           7580
# 243          61117  61117  61117  61117          61117          61117
# 245           2768   2768   2768   2768           2768           2768
# 248           8428   8428   8428   8428           8428           8428
# 249          61333  61333  61333  61333          61333          61333
# 250          14648  14648  14648  14648          14648          14648
# 251           3672   3672   3672   3672           3672           3672
# 252          10798  10798  10798  10798          10798          10798
# 253          25142  25142  25142  25142          25142          25142
# 254           7302   7302   7302   7302           7302           7302
# 255          61015  61015  61015  61015          61015          61015
# 256          61271  61271  61271  61271          61271          61271
# 257          27777  27777  27777  27777          27777          27777
# 258          15989  15989  15989  15989          15989          15989
# 259          22737  22737  22737  22737          22737          22737
# 260          61284  61284  61284  61284          61284          61284
# 261          61252  61252  61252  61252          61252          61252
# 262          61341  61341  61341  61341          61341          61341
# 264          22693  22693  22693  22693          22693          22693
#
#              Fare_Amount  Surcharge  Tip_Amount  Tolls_Amount  Total_Amount  \
# Location_ID
# 1                  62038      62038       62038         62038         62038
# 2                   8656       8656        8656          8656          8656
# 3                   7416       7416        7416          7416          7416
# 4                  62051      62051       62051         62051         62051
# 5                    720        720         720           720           720
# 6                   7837       7837        7837          7837          7837
# 7                  62072      62072       62072         62072         62072
# 8                  60296      60296       60296         60296         60296
# 9                   6113       6113        6113          6113          6113
# 10                 56788      56788       56788         56788         56788
# 11                 15587      15587       15587         15587         15587
# 12                 61923      61923       61923         61923         61923
# 13                 62014      62014       62014         62014         62014
# 14                 33844      33844       33844         33844         33844
# 15                  7586       7586        7586          7586          7586
# 16                  5949       5949        5949          5949          5949
# 17                 40581      40581       40581         40581         40581
# 18                  7393       7393        7393          7393          7393
# 19                 24451      24451       24451         24451         24451
# 20                  5437       5437        5437          5437          5437
# 21                 15690      15690       15690         15690         15690
# 23                 34282      34282       34282         34282         34282
# 24                 62077      62077       62077         62077         62077
# 25                 62052      62052       62052         62052         62052
# 26                 20038      20038       20038         20038         20038
# 27                 13432      13432       13432         13432         13432
# 28                 55216      55216       55216         55216         55216
# 29                 16294      16294       16294         16294         16294
# 30                 10155      10155       10155         10155         10155
# 31                  4192       4192        4192          4192          4192
# ...                  ...        ...         ...           ...           ...
# 229                62083      62083       62083         62083         62083
# 230                62082      62082       62082         62082         62082
# 231                62069      62069       62069         62069         62069
# 232                58136      58136       58136         58136         58136
# 233                62067      62067       62067         62067         62067
# 234                62081      62081       62081         62081         62081
# 235                19012      19012       19012         19012         19012
# 236                62083      62083       62083         62083         62083
# 238                61396      61396       61396         61396         61396
# 240                22137      22137       22137         22137         22137
# 241                 9224       9224        9224          9224          9224
# 242                 7580       7580        7580          7580          7580
# 243                61117      61117       61117         61117         61117
# 245                 2768       2768        2768          2768          2768
# 248                 8428       8428        8428          8428          8428
# 249                61333      61333       61333         61333         61333
# 250                14648      14648       14648         14648         14648
# 251                 3672       3672        3672          3672          3672
# 252                10798      10798       10798         10798         10798
# 253                25142      25142       25142         25142         25142
# 254                 7302       7302        7302          7302          7302
# 255                61015      61015       61015         61015         61015
# 256                61271      61271       61271         61271         61271
# 257                27777      27777       27777         27777         27777
# 258                15989      15989       15989         15989         15989
# 259                22737      22737       22737         22737         22737
# 260                61284      61284       61284         61284         61284
# 261                61252      61252       61252         61252         61252
# 262                61341      61341       61341         61341         61341
# 264                22693      22693       22693         22693         22693
#
#              Tip_Rate  Surcharge_Rate  Mile_Per_Dollar  Count
# Location_ID
# 1               62038           62038            62038  62038
# 2                8652            8652             8656   8656
# 3                7415            7415             7416   7416
# 4               62051           62051            62051  62051
# 5                 720             720              720    720
# 6                7827            7827             7836   7837
# 7               62072           62072            62072  62072
# 8               60290           60290            60294  60296
# 9                6109            6109             6113   6113
# 10              56746           56746            56759  56788
# 11              15558           15556            15576  15587
# 12              61923           61923            61923  61923
# 13              62014           62014            62014  62014
# 14              33829           33829            33840  33844
# 15               7579            7579             7586   7586
# 16               5947            5947             5949   5949
# 17              40575           40575            40578  40581
# 18               7389            7389             7393   7393
# 19              24408           24404            24434  24451
# 20               5436            5435             5437   5437
# 21              15675           15675            15684  15690
# 23              34222           34212            34250  34282
# 24              62077           62077            62077  62077
# 25              62052           62052            62052  62052
# 26              20023           20023            20036  20038
# 27              13431           13431            13338  13432
# 28              55187           55187            55209  55216
# 29              16280           16279            16287  16294
# 30              10153           10153            10155  10155
# 31               4190            4190             4192   4192
# ...               ...             ...              ...    ...
# 229             62083           62083            62083  62083
# 230             62082           62082            62082  62082
# 231             62069           62069            62069  62069
# 232             58133           58133            58135  58136
# 233             62067           62067            62067  62067
# 234             62081           62081            62081  62081
# 235             18998           18998            19010  19012
# 236             62083           62083            62083  62083
# 238             61396           61396            61396  61396
# 240             22112           22107            22129  22137
# 241              9217            9217             9223   9224
# 242              7574            7574             7580   7580
# 243             61117           61117            61117  61117
# 245              2764            2763             2767   2768
# 248              8422            8422             8424   8428
# 249             61333           61333            61333  61333
# 250             14641           14640            14647  14648
# 251              3662            3662             3671   3672
# 252             10781           10780            10796  10798
# 253             25119           25118            25135  25142
# 254              7298            7298             7297   7302
# 255             61015           61015            61015  61015
# 256             61270           61270            61271  61271
# 257             27767           27767            27773  27777
# 258             15977           15977            15983  15989
# 259             22708           22703            22718  22737
# 260             61284           61284            61284  61284
# 261             61252           61252            61252  61252
# 262             61341           61341            61341  61341
# 264             22683           22682            22688  22693
#
# [238 rows x 15 columns]

# %%
taxi_mht_2009 = taxi_2009.loc[taxi_2009['Location_ID'].isin(mht)]
taxi_mht_2010 = taxi_2010.loc[taxi_2010['Location_ID'].isin(mht)]
taxi_mht_2011 = taxi_2011.loc[taxi_2011['Location_ID'].isin(mht)]
taxi_mht_2012 = taxi_2012.loc[taxi_2012['Location_ID'].isin(mht)]
taxi_mht_2013 = taxi_2013.loc[taxi_2013['Location_ID'].isin(mht)]
taxi_mht_2014 = taxi_2014.loc[taxi_2014['Location_ID'].isin(mht)]
taxi_mht_2015 = taxi_2015.loc[taxi_2015['Location_ID'].isin(mht)]

# %%
taxi_mht.plot(kind='bar',width=0.8,rot=0, color = 'pink', alpha= 0.5, edgecolor='g')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2f1b81317958> in <module>()
# ----> 1 taxi_mht.plot(kind='bar',width=0.8,rot=0, color = 'pink', alpha= 0.5, edgecolor='g')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3665                           fontsize=fontsize, colormap=colormap, table=table,
#    3666                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3667                           sort_columns=sort_columns, **kwds)
#    3668     __call__.__doc__ = plot_frame.__doc__
#    3669
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2550                  yerr=yerr, xerr=xerr,
#    2551                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2552                  **kwds)
#    2553
#    2554
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2378         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2379
# -> 2380     plot_obj.generate()
#    2381     plot_obj.draw()
#    2382     return plot_obj.result
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     983         self._compute_plot_data()
#     984         self._setup_subplots()
# --> 985         self._make_plot()
#     986         self._add_table()
#     987         self._make_legend()
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1916                 w = self.bar_width / K
#    1917                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
# -> 1918                                   start=start, label=label, log=self.log, **kwds)
#    1919             self._add_legend_handle(rect, label, index=i)
#    1920
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1866     @classmethod
#    1867     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1868         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1869
#    1870     @property
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2135             r.get_path()._interpolation_steps = 100
#    2136             #print r.get_label(), label, 'label' in kwargs
# -> 2137             self.add_patch(r)
#    2138             patches.append(r)
#    2139
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    1761         if p.get_clip_path() is None:
#    1762             p.set_clip_path(self.patch)
# -> 1763         self._update_patch_limits(p)
#    1764         self.patches.append(p)
#    1765         p._remove_method = lambda h: self.patches.remove(h)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_patch_limits(self, patch)
#    1781         vertices = patch.get_path().vertices
#    1782         if vertices.size > 0:
# -> 1783             xys = patch.get_patch_transform().transform(vertices)
#    1784             if patch.get_data_transform() != self.transData:
#    1785                 patch_to_data = (patch.get_data_transform() -
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.pyc in get_patch_transform(self)
#     668
#     669     def get_patch_transform(self):
# --> 670         self._update_patch_transform()
#     671         return self._rect_transform
#     672
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.pyc in _update_patch_transform(self)
#     662         height = self.convert_yunits(self._height)
#     663         bbox = transforms.Bbox.from_bounds(x, y, width, height)
# --> 664         rot_trans = transforms.Affine2D()
#     665         rot_trans.rotate_deg_around(x, y, self._angle)
#     666         self._rect_transform = transforms.BboxTransformTo(bbox)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.pyc in __init__(self, matrix, **kwargs)
#    1787         If *matrix* is None, initialize with the identity transform.
#    1788         """
# -> 1789         Affine2DBase.__init__(self, **kwargs)
#    1790         if matrix is None:
#    1791             matrix = np.identity(3)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.pyc in __init__(self, *args, **kwargs)
#    1632
#    1633     def __init__(self, *args, **kwargs):
# -> 1634         Transform.__init__(self, *args, **kwargs)
#    1635         self._inverted = None
#    1636
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.pyc in __init__(self, shorthand_name)
#      96         # parents are deleted, references from the children won't keep
#      97         # them alive.
# ---> 98         self._parents = WeakValueDictionary()
#      99
#     100         # TransformNodes start out as invalid until their values are
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/weakref.pyc in __init__(self, *args, **kw)
#      46
#      47     def __init__(self, *args, **kw):
# ---> 48         def remove(wr, selfref=ref(self)):
#      49             self = selfref()
#      50             if self is not None:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 175, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2908, in run_cell
#     self.events.trigger('post_execute')
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/events.py", line 74, in trigger
#     func(*args, **kwargs)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.py", line 113, in flush_figures
#     return show(True)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.py", line 36, in show
#     display(figure_manager.canvas.figure)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/display.py", line 159, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py", line 175, in format
#     data = formatter(obj)
#
#   File "<decorator-gen-9>", line 2, in __call__
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py", line 220, in catch_format_error
#     r = method(self, *args, **kwargs)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py", line 337, in __call__
#     return printer(obj)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 207, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 117, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py", line 2188, in print_figure
#     bbox = a.get_window_extent(renderer)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.py", line 535, in get_window_extent
#     return self.get_path().get_extents(self.get_transform())
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.py", line 195, in get_transform
#     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.py", line 670, in get_patch_transform
#     self._update_patch_transform()
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/patches.py", line 666, in _update_patch_transform
#     self._rect_transform = transforms.BboxTransformTo(bbox)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.py", line 2529, in __init__
#     Affine2DBase.__init__(self, **kwargs)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.py", line 1634, in __init__
#     Transform.__init__(self, *args, **kwargs)
#
#   File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/transforms.py", line 98, in __init__
#     self._parents = WeakValueDictionary()
#
# KeyboardInterrupt

# %%
t09 = taxi_mht_2009.groupby(['Month'])['Count'].sum()
t10 = taxi_mht_2010.groupby(['Month'])['Count'].sum()
t11 = taxi_mht_2011.groupby(['Month'])['Count'].sum()
t12 = taxi_mht_2012.groupby(['Month'])['Count'].sum()
t13 = taxi_mht_2013.groupby(['Month'])['Count'].sum()
t14 = taxi_mht_2014.groupby(['Month'])['Count'].sum()
t15 = taxi_mht_2015.groupby(['Month'])['Count'].sum()
#ttt.plot()#color = 'pink', alpha= 0.5, edgecolor='g')#kind='bar',width=0.8,rot=0,
#ttt

# %%
tot = [t09,t10,t11,t12,t13,t14,t15]
tot = pd.concat(tot)
# Out:
#           Count
# Month
# 1      12883678
# 2      12249244
# 3      13121705
# 4      13034433
# 5      13433410
# 6      12933854
# 7      12390040
# 8      12377006
# 9      12662627
# 10     14142145
# 11     12912072
# 12     13248169
# 1      13500994
# 2      10123334
# 3      11648577
# 4      13621754
# 5      13832974
# 6      13251480
# 7      13081977
# 8      11130706
# 9      13926438
# 10     12732909
# 11     12480495
# 12     12452678
# 1      12114036
# 2      12718459
# 3      14341073
# 4      13189693
# 5      13889132
# 6      13505847
# ...         ...
# 7      12364509
# 8      11235615
# 9      12593074
# 10     13453492
# 11     12850766
# 12     12476382
# 1      12432175
# 2      11831379
# 3      13923874
# 4      13091377
# 5      13040260
# 6      12164410
# 7      11562089
# 8      21378623
# 9      11884286
# 10     12754472
# 11     11849855
# 12     11659294
# 1      11468441
# 2      11162415
# 3      11916588
# 4      11698869
# 5      11721328
# 6      11019154
# 7      10344559
# 8       9916354
# 9      10009750
# 10     11035454
# 11     10138344
# 12     10308047
#
# [84 rows x 1 columns]

# %%
t09 = pd.DataFrame(t09)
t10 = pd.DataFrame(t10)
t11 = pd.DataFrame(t11)
t12 = pd.DataFrame(t12)
t13 = pd.DataFrame(t13)
t14 = pd.DataFrame(t14)
t15 = pd.DataFrame(t15)

# %%
t1 = [t09,t10,t11,t12,t13,t14,t15]
tt = pd.concat(t1,axis=1)

# %%
tt.plot()

# %% [markdown]
# # nbhd demands

# %%
mht = [4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263]
brkl = [11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257]
brx = [3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259]
qus = [2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260]
sti = [5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251]

# %%
taxi_manhattan = taxi[taxi['Location_ID'].isin(mht)]
taxi_brooklyn = taxi[taxi['Location_ID'].isin(brkl)]
taxi_bronx = taxi[taxi['Location_ID'].isin(brx)]
taxi_queens = taxi[taxi['Location_ID'].isin(qus)]
taxi_stisland = taxi[taxi['Location_ID'].isin(sti)]

# %%
demand_manhattan = taxi_manhattan.groupby(['Year'])['Count'].sum()
demand_brooklyn = taxi_brooklyn.groupby(['Year'])['Count'].sum()
demand_bronx = taxi_bronx.groupby(['Year'])['Count'].sum()
demand_queens = taxi_queens.groupby(['Year'])['Count'].sum()
demand_stisland = taxi_stisland.groupby(['Year'])['Count'].sum()

# %%
#(demand_manhattan, demand_brooklyn,demand_bronx,demand_queens,demand_stisland) = plt.subplots(5,1, sharex=True)
plt.figure(figsize=(10,15))
#plt.setp(figure, linestyle='-o', linewidth = 2)  

plt.subplot(511)
demand_manhattan.plot(title='Manhattan', linewidth = 5, color = 'gold')

plt.subplot(512)
demand_brooklyn.plot(title = 'Brooklyn', linewidth = 5, color = 'firebrick')
plt.subplot(513)
demand_queens.plot(title = 'Queens', linewidth = 5, color = 'sage')
plt.subplot(514)
demand_bronx.plot(title = 'Bronx', linewidth = 5,color = 'teal')
plt.subplot(515)
demand_stisland.plot(title = 'Staten Island', linewidth = 5,color = 'indigo')

plt.tight_layout()

# %%
uber_si = uber2014[uber2014['Location_ID'].isin(sti)]
uber_si = uber_si.groupby(['Year','Month'])['date'].count()
uber_si.plot(title = 'Staten Island', linewidth = 5,color = 'indigo')

# %%
demand_stislandlala = taxi_stisland.groupby(['Year','Month'])['Count'].sum()
demand_stislandlala = pd.DataFrame(demand_stislandlala)
demand_stislandlala = np.asanyarray(demand_stislandlala)

# %%
uber_si = pd.DataFrame(uber_si)
uber_si = np.asanyarray(uber_si)

# %%
plt.plot(uber_si,'r')
plt.plot(demand_stislandlala,'g')

# %%
demand_manhattanla = taxi_manhattan.groupby(['Year','Month','Date'])['Count'].sum()
demand_brooklynla = taxi_brooklyn.groupby(['Year','Month','Date'])['Count'].sum()
demand_bronxla = taxi_bronx.groupby(['Year','Month','Date'])['Count'].sum()
demand_queensla = taxi_queens.groupby(['Year','Month','Date'])['Count'].sum()
demand_stislandla = taxi_stisland.groupby(['Year','Month','Date'])['Count'].sum()

# %%
plt.figure(figsize=(10,15))
#plt.setp(figure, linestyle='-o', linewidth = 2)  

plt.subplot(511)
demand_manhattanla.plot(title='Manhattan', linewidth = 1, color = 'gold')

plt.subplot(512)
demand_brooklynla.plot(title = 'Brooklyn', linewidth = 1, color = 'firebrick')
plt.subplot(513)
demand_queensla.plot(title = 'Queens', linewidth = 1, color = 'sage')
plt.subplot(514)
demand_bronxla.plot(title = 'Bronx', linewidth = 1,color = 'teal')
plt.subplot(515)
demand_stislandla.plot(title = 'Staten Island', linewidth = 1,color = 'indigo')

plt.tight_layout()
